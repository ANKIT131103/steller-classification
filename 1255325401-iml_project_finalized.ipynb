# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("F:\IML project Stellar\star_classification.csv")

# %%
df
# Out:
#              obj_ID       alpha      delta         u         g         r  \
# 0      1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1      1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2      1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3      1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4      1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
# ...             ...         ...        ...       ...       ...       ...
# 99995  1.237679e+18   39.620709  -2.594074  22.16759  22.97586  21.90404
# 99996  1.237679e+18   29.493819  19.798874  22.69118  22.38628  20.45003
# 99997  1.237668e+18  224.587407  15.700707  21.16916  19.26997  18.20428
# 99998  1.237661e+18  212.268621  46.660365  25.35039  21.63757  19.91386
# 99999  1.237661e+18  196.896053  49.464643  22.62171  21.79745  20.60115
#
#               i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# ...

# %%
df['class'].value_counts()
# Out:
# GALAXY    59445
# STAR      21594
# QSO       18961
# Name: class, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   obj_ID       100000 non-null  float64
#  1   alpha        100000 non-null  float64
#  2   delta        100000 non-null  float64
#  3   u            100000 non-null  float64
#  4   g            100000 non-null  float64
#  5   r            100000 non-null  float64
#  6   i            100000 non-null  float64
#  7   z            100000 non-null  float64
#  8   run_ID       100000 non-null  int64
#  9   rerun_ID     100000 non-null  int64
#  10  cam_col      100000 non-null  int64
#  11  field_ID     100000 non-null  int64
#  12  spec_obj_ID  100000 non-null  float64
#  13  class        100000 non-null  object
#  14  redshift     100000 non-null  float64
#  15  plate        100000 non-null  int64
#  16  MJD          100000 non-null  int64
#  17  fiber_ID     100000 non-null  int64
# ...

# %%
df.describe()
# Out:
#              obj_ID          alpha          delta              u  \
# count  1.000000e+05  100000.000000  100000.000000  100000.000000
# mean   1.237665e+18     177.629117      24.135305      21.980468
# std    8.438560e+12      96.502241      19.644665      31.769291
# min    1.237646e+18       0.005528     -18.785328   -9999.000000
# 25%    1.237659e+18     127.518222       5.146771      20.352353
# 50%    1.237663e+18     180.900700      23.645922      22.179135
# 75%    1.237668e+18     233.895005      39.901550      23.687440
# max    1.237681e+18     359.999810      83.000519      32.781390
#
#                    g              r              i              z  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       20.531387      19.645762      19.084854      18.668810
# std        31.750292       1.854760       1.757895      31.728152
# min     -9999.000000       9.822070       9.469903   -9999.000000
# ...

# %%
labels = df['class'].unique()
print(labels)
# Out:
# ['GALAXY' 'QSO' 'STAR']

# %%
#to check the null values
df.isnull().sum()

#the dataset does not have null values
# Out:
# obj_ID         0
# alpha          0
# delta          0
# u              0
# g              0
# r              0
# i              0
# z              0
# run_ID         0
# rerun_ID       0
# cam_col        0
# field_ID       0
# spec_obj_ID    0
# class          0
# redshift       0
# plate          0
# MJD            0
# fiber_ID       0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
z=df['class']
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(z)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='class', data=df, palette="Set3")
plt.title("Class Distribution", fontsize=10)
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'class' is the column representing the encoded class labels
class_distribution = df['class'].value_counts()

# Define labels for the pie chart
class_labels = {0: 'GALAXY', 1: 'STAR', 2: 'QSO'}

# Plotting a pie chart
plt.figure(figsize=(8, 8))
plt.pie(class_distribution, labels=class_labels.values(), autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Classes')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'alpha', 'delta', 'u', 'g', 'r', 'i','z', 'redshift' are numerical columns in your dataset

numerical_variables = ['alpha', 'delta', 'u', 'g', 'r', 'i','z', 'redshift']

# Boxplot
plt.figure(figsize=(14, 8))
for var in numerical_variables:
    plt.subplot(2, 4, numerical_variables.index(var) + 1)
    sns.boxplot(x='class', y=var, data=df, palette='Set3')
    plt.title(f'Boxplot of {var} by Class')

plt.tight_layout()
plt.show()

# Histogram
plt.figure(figsize=(14, 8))
for var in numerical_variables:
    plt.subplot(2, 4, numerical_variables.index(var) + 1)
    sns.histplot(df[var], kde=True, bins=30, color='skyblue')
    plt.title(f'Histogram of {var}')

plt.tight_layout()
plt.show()

# %% [markdown]
# From the above boxplots, it is clear that columns - u, g, and z have one outlier value that belongs to the STAR class. The outlier value is located in the
# 79543 index of the dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def pdf_plotter(df, features, target):
    for feature in features:
        plt.figure(figsize=(8, 6))
        for class_label in df[target].unique():
            subset = df[df[target] == class_label]
            sns.kdeplot(subset[feature], label=class_label, shade=True)
        plt.title(f'Probability Density Function for {feature} by {target}')
        plt.xlabel(feature)
        plt.ylabel('Density')
        plt.legend()
        plt.show()

# %%
df.dtypes
# Out:
# obj_ID         float64
# alpha          float64
# delta          float64
# u              float64
# g              float64
# r              float64
# i              float64
# z              float64
# run_ID           int64
# rerun_ID         int64
# cam_col          int64
# field_ID         int64
# spec_obj_ID    float64
# class           object
# redshift       float64
# plate            int64
# MJD              int64
# fiber_ID         int64
# dtype: object

# %%
imp_cols = ['alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'redshift']

# %%
display(df[df['u'] == min(df['u'])][imp_cols + ['class']])
# Out:
#             alpha     delta       u       g        r         i       z  \
# 79543  224.006526 -0.624304 -9999.0 -9999.0  18.1656  18.01675 -9999.0
#
#        redshift class
# 79543  0.000089  STAR

# %%
display(df[imp_cols].describe().T)
# Out:
#              count        mean        std          min         25%  \
# alpha     100000.0  177.629117  96.502241     0.005528  127.518222
# delta     100000.0   24.135305  19.644665   -18.785328    5.146771
# u         100000.0   21.980468  31.769291 -9999.000000   20.352353
# g         100000.0   20.531387  31.750292 -9999.000000   18.965230
# r         100000.0   19.645762   1.854760     9.822070   18.135828
# i         100000.0   19.084854   1.757895     9.469903   17.732285
# z         100000.0   18.668810  31.728152 -9999.000000   17.460677
# redshift  100000.0    0.576661   0.730707    -0.009971    0.054517
#
#                  50%         75%         max
# alpha     180.900700  233.895005  359.999810
# delta      23.645922   39.901550   83.000519
# u          22.179135   23.687440   32.781390
# g          21.099835   22.123767   31.602240
# r          20.125290   21.044785   29.571860
# i          19.405145   20.396495   32.141470
# ...

# %%
display(df[df['u'] == min(df['u'])][imp_cols + ['class']])
# Out:
#             alpha     delta       u       g        r         i       z  \
# 79543  224.006526 -0.624304 -9999.0 -9999.0  18.1656  18.01675 -9999.0
#
#        redshift class
# 79543  0.000089  STAR

# %%
display(df[df['g'] == min(df['g'])][imp_cols + ['class']])
# Out:
#             alpha     delta       u       g        r         i       z  \
# 79543  224.006526 -0.624304 -9999.0 -9999.0  18.1656  18.01675 -9999.0
#
#        redshift class
# 79543  0.000089  STAR

# %%
display(df[df['z'] == min(df['z'])][imp_cols + ['class']])
# Out:
#             alpha     delta       u       g        r         i       z  \
# 79543  224.006526 -0.624304 -9999.0 -9999.0  18.1656  18.01675 -9999.0
#
#        redshift class
# 79543  0.000089  STAR

# %% [markdown]
# Removing the outlier index from the dataset.

# %%
df = df.drop(index=[79543])
print("The shape of the dataset: {}".format(df.shape))
# Out:
# The shape of the dataset: (99999, 18)

# %%
def box_plotter(df, features, target):
    """
    This is funtion helps in plotting the boxplot of data.
    
    Parameters
    ----------
    `df`: dataset
    `features`: columns for analysis
    `target`: target column name
    
    Returns none.
    """
    plt.figure(figsize=(15, 30))
    for (i, feature) in zip(range(len(features)), features):
        plt.subplot(int('{}2{}'.format(len(features), i+1)))
        sns.boxplot(x=target, y=feature, data=df,
                    width=0.5, flierprops={'marker': 'x'})
        plt.title(label='Boxplot of {}'.format(feature), fontsize=10)
        plt.xlabel(xlabel=None)
        plt.ylabel(ylabel=None)
        i += 1
    plt.show()

# %%
box_plotter(df=df, features=imp_cols, target='class')

# %% [markdown]
# The boxplot of the columns - u, g, and z, looks better as I removed the outlier value from the dataset. However, when I observe the box plot of the redshift column, I see that the redshift values for the STAR class are almost
# 0.

# %% [markdown]
# PDF plots for univariate analysis

# %%
imp_cols_pdf = ['u', 'g', 'r', 'i', 'z']
pdf_plotter(df=df, features=imp_cols, target='class')
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\chinm\AppData\Local\Temp\ipykernel_27140\3539255182.py:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(subset[feature], label=class_label, shade=True)
# C:\Users\chinm\AppData\Local\Temp\ipykernel_27140\3539255182.py:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(subset[feature], label=class_label, shade=True)
# C:\Users\chinm\AppData\Local\Temp\ipykernel_27140\3539255182.py:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(subset[feature], label=class_label, shade=True)
# C:\Users\chinm\AppData\Local\Temp\ipykernel_27140\3539255182.py:9: FutureWarning:
#
# ...

# %% [markdown]
# With the exception of the redshift column, all of the density graphs shown above appear to overlap. The STAR class in the redshift column density diagram has all values that are less than 0. The columns' kernel density charts deviate from the Gaussian distribution.

# %% [markdown]
# Pairplots for multivariate analysis

# %%
g = sns.pairplot(data=df[['alpha', 'delta', 'redshift', 'class']], hue='class')
g.fig.suptitle(t='Pair Plot - Stellar Data', y=1.02)
plt.show()

# %% [markdown]
# Clearly, we cannot see any correlation in the above pairplot for the columns - alpha, delta and redshift.

# %%
plt.figure(figsize=(5, 3))
sns.heatmap(data=df[['alpha', 'delta', 'redshift']].corr(),
            annot=True, fmt='.2f', linewidths=0.1)
plt.show()

# %% [markdown]
# Pairplot and correlation plot for photometric filter columns - u, g, r, i, z.

# %%
g = sns.pairplot(data=df[['u', 'g', 'r', 'i', 'z', 'class']], hue='class')
g.fig.suptitle(t='Pair Plot - Stellar Data', y=1.02)
plt.show()

# %% [markdown]
# There is a positive correlation among the photometric filter columns - u, g, r, i, z.

# %%
plt.figure(figsize=(5, 3))
sns.heatmap(data=df[['u', 'g', 'r', 'i', 'z']].corr(),
            annot=True, fmt='.2f', linewidths=0.1)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Exclude non-numeric columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Create a heatmap of the correlation matrix
f, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(numeric_df.corr(), cmap="PuBu", annot=True, linewidths=0.5, fmt='.2f', ax=ax)

# Display the plot
plt.show()

# %%
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
corr_matrix = df[numeric_columns].corr()
print(corr_matrix)
# Out:
#                obj_ID     alpha     delta         u         g         r  \
# obj_ID       1.000000 -0.013726 -0.301268  0.131567  0.151478  0.153879
# alpha       -0.013726  1.000000  0.138698 -0.000222 -0.014118 -0.022079
# delta       -0.301268  0.138698  1.000000 -0.026845 -0.007077 -0.006845
# u            0.131567 -0.000222 -0.026845  1.000000  0.853350  0.728681
# g            0.151478 -0.014118 -0.007077  0.853350  1.000000  0.932996
# r            0.153879 -0.022079 -0.006845  0.728681  0.932996  1.000000
# i            0.147661 -0.023577 -0.004488  0.618346  0.847046  0.962868
# z            0.140463 -0.025160 -0.006286  0.545760  0.775302  0.919114
# run_ID       1.000000 -0.013728 -0.301270  0.131566  0.151477  0.153878
# rerun_ID          NaN       NaN       NaN       NaN       NaN       NaN
# cam_col     -0.047016  0.019587  0.032553  0.007673  0.007828  0.008472
# field_ID     0.031544 -0.165593 -0.173393 -0.013365 -0.022149 -0.026405
# ...

# %%
df = df.drop(['obj_ID','alpha','delta','run_ID','rerun_ID','cam_col','field_ID','fiber_ID'], axis = 1)

# %%
df['class']
# Out:
# 0        GALAXY
# 1        GALAXY
# 2        GALAXY
# 3        GALAXY
# 4        GALAXY
#           ...
# 99995    GALAXY
# 99996    GALAXY
# 99997    GALAXY
# 99998    GALAXY
# 99999    GALAXY
# Name: class, Length: 99999, dtype: object

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
x = df.drop(['class'], axis = 1)
y = df['class']

# %%
df
# Out:
#               u         g         r         i         z   spec_obj_ID   class  \
# 0      23.87882  22.27530  20.39501  19.16573  18.79371  6.543777e+18  GALAXY
# 1      24.77759  22.83188  22.58444  21.16812  21.61427  1.176014e+19  GALAXY
# 2      25.26307  22.66389  20.60976  19.34857  18.94827  5.152200e+18  GALAXY
# 3      22.13682  23.77656  21.61162  20.50454  19.25010  1.030107e+19  GALAXY
# 4      19.43718  17.58028  16.49747  15.97711  15.54461  6.891865e+18  GALAXY
# ...         ...       ...       ...       ...       ...           ...     ...
# 99995  22.16759  22.97586  21.90404  21.30548  20.73569  1.055431e+19  GALAXY
# 99996  22.69118  22.38628  20.45003  19.75759  19.41526  8.586351e+18  GALAXY
# 99997  21.16916  19.26997  18.20428  17.69034  17.35221  3.112008e+18  GALAXY
# 99998  25.35039  21.63757  19.91386  19.07254  18.62482  7.601080e+18  GALAXY
# 99999  22.62171  21.79745  20.60115  20.00959  19.28075  8.343152e+18  GALAXY
#
#        redshift  plate    MJD
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['class'] = label_encoder.fit_transform(df['class'])
df.dtypes
# Out:
# u              float64
# g              float64
# r              float64
# i              float64
# z              float64
# spec_obj_ID    float64
# class            int32
# redshift       float64
# plate            int64
# MJD              int64
# dtype: object

# %%
df['class'].value_counts()
# Out:
# 0    59445
# 2    21593
# 1    18961
# Name: class, dtype: int64

# %% [markdown]
# Feature engineering and feature importance {-}
#
# Data splitting

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x)
x = scaler.transform(x)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.metrics import confusion_matrix, classification_report


from yellowbrick.classifier import ConfusionMatrix
from yellowbrick.classifier import ClassPredictionError
from yellowbrick.classifier import ROCAUC
from yellowbrick.style import set_palette

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.33, random_state = 42)

# %% [markdown]
# #Classifier 1: Support Vector Machine (SVM)

# %%
svm_clf = svm.SVC(kernel='rbf', C=1, random_state=0)
svm_clf.fit(x_train,y_train)
predicted = svm_clf.predict(x_test)
score = svm_clf.score(x_test, y_test)
svm_score_ = np.mean(score)

print('Accuracy : %.3f' % (svm_score_))
# Out:
# Accuracy : 0.963

# %%
classes = ['GALAXY','STAR','QSO']
from yellowbrick.classifier import ConfusionMatrix

# Assuming 'classes' is a list of class labels

# Initialize the ConfusionMatrix with the SVM classifier, class labels, and colormap
confusion_matrix_svm = ConfusionMatrix(svm_clf, classes=classes, cmap='GnBu')

# Fit the ConfusionMatrix on the training data
confusion_matrix_svm.fit(x_train, y_train)

# Evaluate and score the ConfusionMatrix on the test data
confusion_matrix_svm.score(x_test, y_test)

# Display the confusion matrix visualization
confusion_matrix_svm.show()
# Out:
# <Axes: title={'center': 'SVC Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
print(classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#       GALAXY       0.97      0.97      0.97     19590
#          QSO       0.97      0.91      0.94      6306
#         STAR       0.95      1.00      0.97      7104
#
#     accuracy                           0.96     33000
#    macro avg       0.96      0.96      0.96     33000
# weighted avg       0.96      0.96      0.96     33000

# %%
visualizer_svm = ROCAUC(svm_clf, classes=classes)

set_palette('bold')

visualizer_svm.fit(x_train, y_train)        
visualizer_svm.score(x_test, y_test)        
visualizer_svm.show()
# Out:
# <Axes: title={'center': 'ROC Curves for SVC'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %% [markdown]
# #Classifier 2: Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# Create a Random Forest classifier
random_forest = RandomForestClassifier()

# Train the Random Forest classifier on the training data
random_forest.fit(x_train, y_train)

# Make predictions on the test data
predicted_labels_rf = random_forest.predict(x_test)

# Calculate the accuracy score of the Random Forest model on the test set
accuracy_rf = random_forest.score(x_test, y_test)
average_accuracy_rf = np.mean(accuracy_rf)

# Print the accuracy score
print('Accuracy: %.3f' % average_accuracy_rf)
# Out:
# Accuracy: 0.978

# %%
from yellowbrick.classifier import ConfusionMatrix

# Assuming 'classes' is a list of class labels

# Initialize the ConfusionMatrix for visualizing the Random Forest classifier's performance
rf_confusion_matrix = ConfusionMatrix(random_forest, classes=classes, cmap='GnBu')

# Fit the ConfusionMatrix on the training data
rf_confusion_matrix.fit(x_train, y_train)

# Evaluate and score the ConfusionMatrix on the test data
rf_confusion_matrix.score(x_test, y_test)

# Show the visualization of the confusion matrix
rf_confusion_matrix.show()
# Out:
# <Axes: title={'center': 'RandomForestClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
print(classification_report(y_test, predicted_labels_rf))
# Out:
#               precision    recall  f1-score   support
#
#       GALAXY       0.98      0.99      0.98     19590
#          QSO       0.97      0.93      0.95      6306
#         STAR       1.00      1.00      1.00      7104
#
#     accuracy                           0.98     33000
#    macro avg       0.98      0.97      0.97     33000
# weighted avg       0.98      0.98      0.98     33000

# %%
from yellowbrick.classifier import ROCAUC
from yellowbrick.style import set_palette

# Assuming 'classes' is a list of class labels

# Create an instance of the ROCAUC visualizer for the Random Forest classifier
roc_auc_visualizer = ROCAUC(random_forest, classes=["GALAXY", "STAR", "QSO"])

# Set a bold palette for the visualizer
set_palette('bold')

# Fit the ROCAUC visualizer on the training data
roc_auc_visualizer.fit(x_train, y_train)

# Score the ROCAUC visualizer on the test data
roc_auc_visualizer.score(x_test, y_test)

# Show the visualization of the ROC curve
roc_auc_visualizer.show()
# Out:
# <Axes: title={'center': 'ROC Curves for RandomForestClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %% [markdown]
# #Classifier 3: Logistic Regression

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings('ignore')

# Define the parameter grid for Logistic Regression
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'penalty': ['l1', 'l2'],
              'solver': ['liblinear', 'saga']}

# Create a Logistic Regression classifier
logreg_classifier = LogisticRegression(random_state=0)

# Create an instance of GridSearchCV with 3-fold cross-validation
grid_search = GridSearchCV(logreg_classifier, param_grid, cv=3)

# Fit the GridSearchCV on the training data to find the best hyperparameters
grid_search.fit(x_train, y_train)

# Get the best hyperparameters and train the model with them
best_params = grid_search.best_params_
best_logreg_model = LogisticRegression(**best_params, random_state=0)
best_logreg_model.fit(x_train, y_train)

# Evaluate the best Logistic Regression model on the test set
accuracy_logreg = best_logreg_model.score(x_test, y_test)

print('Best Logistic Regression Model Accuracy: %.3f' % accuracy_logreg)
print(best_params)
# Out:
# Best Logistic Regression Model Accuracy: 0.958
# {'C': 10, 'penalty': 'l1', 'solver': 'saga'}

# %%
from yellowbrick.classifier import ConfusionMatrix

# Assuming 'classes' is a list of class labels

# Initialize the ConfusionMatrix for visualizing the Random Forest classifier's performance
logistic_regression_matrix = ConfusionMatrix(logreg_classifier, classes=classes, cmap='GnBu')

# Fit the ConfusionMatrix on the training data
logistic_regression_matrix.fit(x_train, y_train)

# Evaluate and score the ConfusionMatrix on the test data
logistic_regression_matrix.score(x_test, y_test)

# Show the visualization of the confusion matrix
logistic_regression_matrix.show()
# Out:
# <Axes: title={'center': 'LogisticRegression Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
visualizer_LG = ROCAUC(logreg_classifier, classes=classes)

set_palette('bold')

visualizer_LG.fit(x_train, y_train)        
visualizer_LG.score(x_test, y_test)        
visualizer_LG.show()
# Out:
# <Axes: title={'center': 'ROC Curves for LogisticRegression'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %% [markdown]
# #Classifier 4: KNN classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# Define the parameter grid for KNN
param_grid = {'n_neighbors': [3, 5, 7, 9, 11],
              'weights': ['uniform', 'distance'],
              'metric': ['euclidean', 'manhattan']}

# Create a KNN classifier
knn_classifier = KNeighborsClassifier()

# Create an instance of GridSearchCV with 3-fold cross-validation
grid_search = GridSearchCV(knn_classifier, param_grid, cv=3)

# Fit the GridSearchCV on the training data to find the best hyperparameters
grid_search.fit(x_train, y_train)

# Get the best hyperparameters and train the model with them
best_params_knn = grid_search.best_params_
best_knn_model = KNeighborsClassifier(n_neighbors=best_params_knn['n_neighbors'],
                                      weights=best_params_knn['weights'],
                                      metric=best_params_knn['metric'])
best_knn_model.fit(x_train, y_train)

# Evaluate the best KNN model on the test set
predicted_labels_knn = best_knn_model.predict(x_test)
accuracy_knn = accuracy_score(y_test, predicted_labels_knn)

print('Best K-Nearest Neighbors Model Accuracy: %.3f' % accuracy_knn)
print(best_params_knn)
# Out:
# Best K-Nearest Neighbors Model Accuracy: 0.955
# {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}

# %%
from yellowbrick.classifier import ConfusionMatrix

# Assuming 'classes' is a list of class labels

# Initialize the ConfusionMatrix for visualizing the Random Forest classifier's performance
KNN_matrix = ConfusionMatrix(knn_classifier, classes=classes, cmap='GnBu')

# Fit the ConfusionMatrix on the training data
KNN_matrix.fit(x_train, y_train)

# Evaluate and score the ConfusionMatrix on the test data
KNN_matrix.score(x_test, y_test)

# Show the visualization of the confusion matrix
KNN_matrix.show()
# Out:
# <Axes: title={'center': 'KNeighborsClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
visualizer_KNN = ROCAUC(knn_classifier, classes=classes)

set_palette('bold')

visualizer_KNN.fit(x_train, y_train)        
visualizer_KNN.score(x_test, y_test)        
visualizer_KNN.show()
# Out:
# <Axes: title={'center': 'ROC Curves for KNeighborsClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %% [markdown]
# #Classifier 5: Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# Define the parameter grid for Decision Tree
param_grid = {'criterion': ['gini', 'entropy'],
              'max_depth': [None, 5, 10, 15],
              'min_samples_split': [2, 5, 10],
              'min_samples_leaf': [1, 2, 4]}

# Create a Decision Tree classifier
dt_classifier = DecisionTreeClassifier(random_state=0)

# Create an instance of GridSearchCV with 3-fold cross-validation
grid_search = GridSearchCV(dt_classifier, param_grid, cv=3)

# Fit the GridSearchCV on the training data to find the best hyperparameters
grid_search.fit(x_train, y_train)

# Get the best hyperparameters and train the model with them
best_params_dt = grid_search.best_params_
print("Best Hyperparameters:", best_params_dt)

# Extract hyperparameters individually
best_criterion = best_params_dt.get('criterion', 'gini')  # Default to 'gini' if 'criterion' not found
best_max_depth = best_params_dt.get('max_depth', None)
best_min_samples_split = best_params_dt.get('min_samples_split', 2)
best_min_samples_leaf = best_params_dt.get('min_samples_leaf', 1)

best_dt_model = DecisionTreeClassifier(criterion=best_criterion,
                                       max_depth=best_max_depth,
                                       min_samples_split=best_min_samples_split,
                                       min_samples_leaf=best_min_samples_leaf,
                                       random_state=0)
best_dt_model.fit(x_train, y_train)

# Evaluate the best Decision Tree model on the test set
predicted_labels_dt = best_dt_model.predict(x_test)
accuracy_dt = accuracy_score(y_test, predicted_labels_dt)

print('Best Decision Tree Model Accuracy: %.3f' % accuracy_dt)
# Out:
# Best Hyperparameters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Best Decision Tree Model Accuracy: 0.974

# %%
from yellowbrick.classifier import ConfusionMatrix

# Assuming 'classes' is a list of class labels

# Initialize the ConfusionMatrix for visualizing the Random Forest classifier's performance
DT_matrix = ConfusionMatrix(dt_classifier, classes=classes, cmap='GnBu')

# Fit the ConfusionMatrix on the training data
DT_matrix.fit(x_train, y_train)

# Evaluate and score the ConfusionMatrix on the test data
DT_matrix.score(x_test, y_test)

# Show the visualization of the confusion matrix
DT_matrix.show()
# Out:
# <Axes: title={'center': 'DecisionTreeClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
visualizer_dt = ROCAUC(dt_classifier, classes=classes)

set_palette('bold')

visualizer_dt.fit(x_train, y_train)        
visualizer_dt.score(x_test, y_test)        
visualizer_dt.show()
# Out:
# <Axes: title={'center': 'ROC Curves for DecisionTreeClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC  # Import SVC from sklearn.svm module
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

classifiers = {
    'knn_classifier': KNeighborsClassifier(),
    'logreg_classifier': LogisticRegression(),
    'svm_clf': SVC(),
    'dt_classifier': DecisionTreeClassifier(),
    'random_forest': RandomForestClassifier()
}

classifier_name = input('Enter the name of the Classifier: ')

if classifier_name in classifiers:
    selected_classifier = classifiers[classifier_name]
    num_features = 9  # Change this to the actual number of features

    selected_classifier.fit(x_train, y_train)
   
    def classify_with_input(classifier):
        # Gather input for each feature
        features = []
        for i in range(num_features):
            feature_value = float(input(f"Enter value for feature {i + 1}: "))
            features.append(feature_value)

        # Reshape features to be in the format expected by the classifier
        input_features = [features]

        # Perform classification using the provided classifier
        prediction = classifier.predict(input_features)

        return prediction

    result = classify_with_input(selected_classifier)
    print("The classification result is:", result)
else:
    print("Invalid classifier name. Please choose from the available classifiers.")
# Out:
# The classification result is: ['GALAXY']
